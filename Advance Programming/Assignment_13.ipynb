# %% [markdown]
# 1.Create a function that takes a list and string. The function should remove the letters in the string from the list, and return the list.
#
# Examples
#
# remove_letters(["s", "t", "r", "i", "n", "g", "w"], "string") ➞ ["w"]
#
# remove_letters(["b", "b", "l", "l", "g", "n", "o", "a", "w"], "balloon") ➞ ["b", "g", "w"]
#
# remove_letters(["d", "b", "t", "e", "a", "i"], "edabit") ➞ []

# %%
def remove_letters(char_list,text):
    for letter in text:
        if letter in char_list:
            char_list.remove(letter)
            
    return char_list

print(remove_letters(["b", "b", "l", "l", "g", "n", "o", "a", "w"], "balloon") )
print(remove_letters(["d", "b", "t", "e", "a", "i"], "edabit"))
# Out:
# ['b', 'g', 'w']
# []

# %% [markdown]
# 2.A block sequence in three dimensions. We can write a formula for this one:
#
# ![image.png](attachment:image.png)
#
# Create a function that takes a number (step) as an argument and returns the amount of blocks in that step.
#
# Examples
#
# blocks(1) ➞ 5
#
# blocks(5) ➞ 39
#
# blocks(2) ➞ 12

# %%
def blocks(step_num):
    sum=5
    add=7
    step_list=[]
    for i in range(1,step_num+1):
        step_list.append(sum)
        sum=sum+add
        add+=1
       
        
    return step_list[-1]

print(blocks(1))
print(blocks(5))
print(blocks(2))
# Out:
# 5
# 39
# 12

# %% [markdown]
# 3.Create a function that subtracts one positive integer from another, without using any arithmetic operators such as -, %, /, +, etc.
#
# Examples
#
# my_sub(5, 9) ➞ 4
#
# my_sub(10, 30) ➞ 20
#
# my_sub(0, 0) ➞ 0

# %%
def my_sub(x,y):
    x_list=[n1 for n1 in range(x)]
    y_list=[n2 for n2 in range(y)]
    
    for n1 in x_list:
        y_list.remove(n1)
        
    return len(y_list)


print(my_sub(5, 9))
print(my_sub(10, 30))
print(my_sub(0, 0))
# Out:
# 4
# 20
# 0

# %% [markdown]
# 4.Create a function that takes a string containing money in dollars and pounds sterling (seperated by comma) and returns the sum of dollar bills only, as an integer.
#
# For the input string:
#
#    - Each amount is prefixed by the currency symbol: $ for dollars and £ for pounds.
#    - Thousands are represented by the suffix k.
#
# i.e. $4k = $4,000 and £40k = £40,000
#
# Examples
#
# add_bill("d20,p40,p60,d50") ➞ 20 + 50 = 70
#
# add_bill("p30,d20,p60,d150,p360") ➞ 20  + 150 = 170
#
# add_bill("p30,d2k,p60,d200,p360") ➞ 2 * 1000 + 200 = 2200

# %%
def add_bill(money_str):
    money_list=money_str.split(',')
    sum=0
    for money in money_list:
        if money.startswith('d'):
            multiply_by=1
            if 'k' in money:
                multiply_by=1000
                money=money.replace('k','')
                
            sum+=int(money.replace('d',''))*multiply_by
            
    return sum

print(add_bill("d20,p40,p60,d50"))
print(add_bill("p30,d20,p60,d150,p360") )
print(add_bill("p30,d2k,p60,d200,p360"))
# Out:
# 70
# 170
# 2200

# %% [markdown]
# 5.Create a function that flips a horizontal list into a vertical list, and a vertical list into a horizontal list.
#
# In other words, take an 1 x n list (1 row + n columns) and flip it into a n x 1 list (n rows and 1 column), and vice versa.
#
# Examples
#
# flip_list([1, 2, 3, 4]) ➞ [[1], [2], [3], [4]]
# #Take a horizontal list and flip it vertical.
#
# flip_list([[5], [6], [9]]) ➞ [5, 6, 9]
# #Take a vertical list and flip it horizontal.
#
# flip_list([]) ➞ []

# %%
def flip_list(num_list):
    flipped_list=[]
    if len(num_list)==0:
        pass
    else:
        if type(num_list[0])==list:
            for l in num_list:
                flipped_list.extend(l)
    
        elif type(num_list[0])==int:
            for num in num_list:
                flipped_list.append([num])
    
    return flipped_list

print(flip_list([1, 2, 3, 4]))   
print(flip_list([[5], [6], [9]]))  
print(flip_list([]))
# Out:
# [[1], [2], [3], [4]]
# [5, 6, 9]
# []
